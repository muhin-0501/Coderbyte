# %%
import numpy
import pandas as pd
import numpy as np
import seaborn as sns                     
import matplotlib.pyplot as plt

# %%
a = pd.read_csv("/content/world_population.csv")
a.head()
# Out:
#    Rank CCA3         Country           Capital Continent  2022 Population  \
# 0    36  AFG     Afghanistan             Kabul      Asia         41128771
# 1   138  ALB         Albania            Tirana    Europe          2842321
# 2    34  DZA         Algeria           Algiers    Africa         44903225
# 3   213  ASM  American Samoa         Pago Pago   Oceania            44273
# 4   203  AND         Andorra  Andorra la Vella    Europe            79824
#
#    2020 Population  2015 Population  2010 Population  2000 Population  \
# 0         38972230         33753499         28189672         19542982
# 1          2866849          2882481          2913399          3182021
# 2         43451666         39543154         35856344         30774621
# 3            46189            51368            54849            58230
# 4            77700            71746            71519            66097
#
#    1990 Population  1980 Population  1970 Population  Area (km²)  \
# ...

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Rank                         234 non-null    int64
#  1   CCA3                         234 non-null    object
#  2   Country                      234 non-null    object
#  3   Capital                      234 non-null    object
#  4   Continent                    234 non-null    object
#  5   2022 Population              234 non-null    int64
#  6   2020 Population              234 non-null    int64
#  7   2015 Population              234 non-null    int64
#  8   2010 Population              234 non-null    int64
#  9   2000 Population              234 non-null    int64
#  10  1990 Population              234 non-null    int64
#  11  1980 Population              234 non-null    int64
#  12  1970 Population              234 non-null    int64
# ...

# %%
a.dtypes
# Out:
# Rank                             int64
# CCA3                            object
# Country                         object
# Capital                         object
# Continent                       object
# 2022 Population                  int64
# 2020 Population                  int64
# 2015 Population                  int64
# 2010 Population                  int64
# 2000 Population                  int64
# 1990 Population                  int64
# 1980 Population                  int64
# 1970 Population                  int64
# Area (km²)                       int64
# Density (per km²)              float64
# Growth Rate                    float64
# World Population Percentage    float64
# dtype: object

# %%
a.shape
# Out:
# (234, 17)

# %%
a.columns
# Out:
# Index(['Rank', 'CCA3', 'Country', 'Capital', 'Continent', '2022 Population',
#        '2020 Population', '2015 Population', '2010 Population',
#        '2000 Population', '1990 Population', '1980 Population',
#        '1970 Population', 'Area (km²)', 'Density (per km²)', 'Growth Rate',
#        'World Population Percentage'],
#       dtype='object')

# %%
a.describe(include='all')
# Out:
#               Rank CCA3      Country Capital Continent  2022 Population  \
# count   234.000000  234          234     234       234     2.340000e+02
# unique         NaN  234          234     234         6              NaN
# top            NaN  AFG  Afghanistan   Kabul    Africa              NaN
# freq           NaN    1            1       1        57              NaN
# mean    117.500000  NaN          NaN     NaN       NaN     3.407441e+07
# std      67.694165  NaN          NaN     NaN       NaN     1.367664e+08
# min       1.000000  NaN          NaN     NaN       NaN     5.100000e+02
# 25%      59.250000  NaN          NaN     NaN       NaN     4.197385e+05
# 50%     117.500000  NaN          NaN     NaN       NaN     5.559944e+06
# 75%     175.750000  NaN          NaN     NaN       NaN     2.247650e+07
# max     234.000000  NaN          NaN     NaN       NaN     1.425887e+09
#
#         2020 Population  2015 Population  2010 Population  2000 Population  \
# ...

# %%
a.describe(include='object')
# Out:
#        CCA3      Country Capital Continent
# count   234          234     234       234
# unique  234          234     234         6
# top     AFG  Afghanistan   Kabul    Africa
# freq      1            1       1        57

# %%
a.nunique()
# Out:
# Rank                           234
# CCA3                           234
# Country                        234
# Capital                        234
# Continent                        6
# 2022 Population                234
# 2020 Population                234
# 2015 Population                234
# 2010 Population                234
# 2000 Population                234
# 1990 Population                234
# 1980 Population                234
# 1970 Population                234
# Area (km²)                     233
# Density (per km²)              234
# Growth Rate                    180
# World Population Percentage     70
# dtype: int64

# %%
a.isna().sum().sort_values(ascending=True)
# Out:
# Rank                           0
# Density (per km²)              0
# Area (km²)                     0
# 1970 Population                0
# 1980 Population                0
# 1990 Population                0
# 2000 Population                0
# Growth Rate                    0
# 2010 Population                0
# 2020 Population                0
# 2022 Population                0
# Continent                      0
# Capital                        0
# Country                        0
# CCA3                           0
# 2015 Population                0
# World Population Percentage    0
# dtype: int64

# %%
a['Continent'].value_counts()
# Out:
# Africa           57
# Asia             50
# Europe           50
# North America    40
# Oceania          23
# South America    14
# Name: Continent, dtype: int64

# %%
plt.figure(figsize=(10,5))
cor = a.corr()
sns.heatmap(cor,cmap="mako",annot=True)

# %%
cor
# Out:
#                                  Rank  2022 Population  2020 Population  \
# Rank                         1.000000        -0.358361        -0.355854
# 2022 Population             -0.358361         1.000000         0.999946
# 2020 Population             -0.355854         0.999946         1.000000
# 2015 Population             -0.351222         0.999490         0.999763
# 2010 Population             -0.347461         0.998629         0.999105
# 2000 Population             -0.341057         0.994605         0.995583
# 1990 Population             -0.336152         0.987228         0.988724
# 1980 Population             -0.335246         0.980285         0.982121
# 1970 Population             -0.335379         0.973162         0.975254
# Area (km²)                  -0.383774         0.453411         0.454993
# Density (per km²)            0.129436        -0.027618        -0.027358
# Growth Rate                 -0.224561        -0.020863        -0.025116
# ...

# %%
ppl_diff_70to22 = a.groupby('Continent')[['1970 Population','2022 Population']].sum().sort_values(by = 'Continent', ascending= True).reset_index()
ppl_diff_70to22
# Out:
#        Continent  1970 Population  2022 Population
# 0         Africa        365444348       1426730932
# 1           Asia       2144906290       4721383274
# 2         Europe        655923991        743147538
# 3  North America        315434606        600296136
# 4        Oceania         19480270         45038554
# 5  South America        192947156        436816608

# %%
ppl_diff_70to22['Percentage'] = round(ppl_diff_70to22['1970 Population']/ ppl_diff_70to22['2022 Population']*100,2)
ppl_diff_70to22
# Out:
#        Continent  1970 Population  2022 Population  Percentage
# 0         Africa        365444348       1426730932       25.61
# 1           Asia       2144906290       4721383274       45.43
# 2         Europe        655923991        743147538       88.26
# 3  North America        315434606        600296136       52.55
# 4        Oceania         19480270         45038554       43.25
# 5  South America        192947156        436816608       44.17

# %%
plt.figure(figsize = (16,8))
plt.plot(ppl_diff_70to22['Continent'],ppl_diff_70to22['1970 Population'], label = '1970', color = 'green', marker = 'o' )
plt.plot(ppl_diff_70to22['Continent'],ppl_diff_70to22['2022 Population'], label = '2022', color = 'blue', marker = 'o')
plt.title('Differnce in Population between 1970 - 2022')
plt.xlabel('CONTINENT')
plt.ylabel('POPULATION')
plt.grid(linewidth = 0.4)
plt.legend()
plt.show()

# %%
plt.figure(figsize= (12,5))
sns.countplot(x = 'Continent', data = wop.sort_values(by = 'Continent', ascending = True), palette= 'mako')
plt.tight_layout()
plt.xlabel('CONTINENT')
plt.ylabel('No. of Countries')
# Out:
# Text(84.375, 0.5, 'No. of Countries')

# %%
data = a.groupby('Continent')['World Population Percentage'].sum().round(1).sort_values(ascending= False).reset_index()
data
# Out:
#        Continent  World Population Percentage
# 0           Asia                         59.2
# 1         Africa                         17.9
# 2         Europe                          9.3
# 3  North America                          7.5
# 4  South America                          5.5
# 5        Oceania                          0.6

# %%
b= data['Continent']
b
# Out:
# 0             Asia
# 1           Africa
# 2           Europe
# 3    North America
# 4    South America
# 5          Oceania
# Name: Continent, dtype: object

# %%
c = data['World Population Percentage']
c
# Out:
# 0    59.2
# 1    17.9
# 2     9.3
# 3     7.5
# 4     5.5
# 5     0.6
# Name: World Population Percentage, dtype: float64

# %%
a.groupby('Country')['2022 Population'].sum().sort_values(ascending=False).head(5)
# Out:
# Country
# China            1425887337
# India            1417173173
# United States     338289857
# Indonesia         275501339
# Pakistan          235824862
# Name: 2022 Population, dtype: int64

# %%
Cp = a.groupby('Country')
Cp.sum().sort_values(by ='2022 Population', ascending = False)['2022 Population'].head(10)
# Out:
# Country
# China            1425887337
# India            1417173173
# United States     338289857
# Indonesia         275501339
# Pakistan          235824862
# Nigeria           218541212
# Brazil            215313498
# Bangladesh        171186372
# Russia            144713314
# Mexico            127504125
# Name: 2022 Population, dtype: int64

# %%
population = a[['Country','2022 Population']].sort_values(by = '2022 Population', ascending = False).head(10).reset_index()
population
# Out:
#    index        Country  2022 Population
# 0     41          China       1425887337
# 1     92          India       1417173173
# 2    221  United States        338289857
# 3     93      Indonesia        275501339
# 4    156       Pakistan        235824862
# 5    149        Nigeria        218541212
# 6     27         Brazil        215313498
# 7     16     Bangladesh        171186372
# 8    171         Russia        144713314
# 9    131         Mexico        127504125

# %%
population.drop(columns = 'index', inplace = True)

# %%
population
# Out:
#          Country  2022 Population
# 0          China       1425887337
# 1          India       1417173173
# 2  United States        338289857
# 3      Indonesia        275501339
# 4       Pakistan        235824862
# 5        Nigeria        218541212
# 6         Brazil        215313498
# 7     Bangladesh        171186372
# 8         Russia        144713314
# 9         Mexico        127504125

# %%
growth = a.sort_values(by = 'Growth Rate', ascending = False).head(10)

# %%
plt.figure(figsize = (16,8))
plt.plot(growth['Country'],growth['2022 Population'],marker = 'o', label = '2022', color = 'green')
plt.plot(growth['Country'],growth['1970 Population'],marker = 'd', label = '1970', color = 'blue')
plt.xlabel('COUNTRY_NAME')
plt.legend()
plt.ylabel('GROWTH_RATE')
plt.title('Top 10 Countries with Highest Growth Rate')
plt.grid(linewidth = 0.6)
plt.show()
